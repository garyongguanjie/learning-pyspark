# %% [markdown]
# # Predicting movie reviews with pyspark
#
# This exercise is to use simple ngram models and logistic regression to predict sentiments in movie reviews
#
# Adapted from:https://towardsdatascience.com/sentiment-analysis-with-pyspark-bc8e83f80c35

# %% [markdown]
# # Install pyspark and download data

# %%
# !pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyspark
#   Downloading pyspark-3.3.0.tar.gz (281.3 MB)
#      |████████████████████████████████| 281.3 MB 33 kB/s
# Collecting py4j==0.10.9.5
#   Downloading py4j-0.10.9.5-py2.py3-none-any.whl (199 kB)
#      |████████████████████████████████| 199 kB 51.1 MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.3.0-py2.py3-none-any.whl size=281764026 sha256=44f6b83e22be9cd59a0b09183c549d09ad16f8614fae7debc540d8f964e0bede
#   Stored in directory: /root/.cache/pip/wheels/7a/8e/1b/f73a52650d2e5f337708d9f6a1750d451a7349a867f928b885
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.5 pyspark-3.3.0

# %%
# !wget https://github.com/garyongguanjie/learning-pyspark/raw/main/data/imdb-movie-review.zip
# !unzip imdb-movie-review.zip
# Out:
# --2022-06-27 07:51:15--  https://github.com/garyongguanjie/learning-pyspark/raw/main/data/imdb-movie-review.zip
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/garyongguanjie/learning-pyspark/main/data/imdb-movie-review.zip [following]
# --2022-06-27 07:51:15--  https://raw.githubusercontent.com/garyongguanjie/learning-pyspark/main/data/imdb-movie-review.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 26962657 (26M) [application/zip]
# Saving to: ‘imdb-movie-review.zip’
#
# imdb-movie-review.z 100%[===================>]  25.71M   168MB/s    in 0.2s
#
# 2022-06-27 07:51:16 (168 MB/s) - ‘imdb-movie-review.zip’ saved [26962657/26962657]
#
# Archive:  imdb-movie-review.zip
#   inflating: IMDB Dataset.csv

# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as F

spark = SparkSession.builder.appName('imdb-nlp-example').getOrCreate()

# %%
df = spark.read.csv('IMDB Dataset.csv',header=True,inferSchema=True,escape='"')

# %%
df.show(5)
# Out:
# +--------------------+---------+
# |              review|sentiment|
# +--------------------+---------+
# |One of the other ...| positive|
# |A wonderful littl...| positive|
# |I thought this wa...| positive|
# |Basically there's...| negative|
# |Petter Mattei's "...| positive|
# +--------------------+---------+
# only showing top 5 rows

# %%
df.printSchema()
# Out:
# root
#  |-- review: string (nullable = true)
#  |-- sentiment: string (nullable = true)

# %% [markdown]
# # EDA

# %%
df.groupBy('sentiment').count().show()
# Out:
# +---------+-----+
# |sentiment|count|
# +---------+-----+
# | positive|25000|
# | negative|25000|
# +---------+-----+

# %% [markdown]
# ## Count top words for each sentinment
#
# Here we remove stopwords so that the count is more accurate

# %%
positive_words = df.filter(df.sentiment == "positive").withColumn('tokens', F.split(F.col('review'), ' '))
negative_words = df.filter(df.sentiment == "negative").withColumn('tokens', F.split(F.col('review'), ' '))

# %%
from pyspark.ml.feature import StopWordsRemover
# slightly ugly here since we are extending the stopwords list

remover = StopWordsRemover(stopWords=["/><br"]+StopWordsRemover.loadDefaultStopWords('english'),inputCol = 'tokens',outputCol='cleaned')

# we can use remover.loadDefaultStopWords('english') if you do not wish to extend the current stop words list

# %%
remover.transform(positive_words).withColumn('word',F.explode('cleaned')).groupby('word').count().sort('count',ascending=False).show()
# Out:
# +------+-----+
# |  word|count|
# +------+-----+
# |  film|28855|
# | movie|26367|
# |   one|21304|
# |  like|15665|
# |  good|11318|
# |   see|10693|
# | great|10331|
# |really|10138|
# | story| 9329|
# |     -| 9182|
# |  also| 9015|
# |  much| 8034|
# |  even| 7999|
# |   get| 7797|
# |  time| 7711|
# | first| 7695|
# |  well| 7157|
# | />The| 7151|
# |  many| 6901|
# |people| 6818|
# +------+-----+
# only showing top 20 rows

# %%
remover.transform(negative_words).withColumn('word',F.explode('cleaned')).groupby('word').count().sort('count',ascending=False).show()
# Out:
# +------+-----+
# |  word|count|
# +------+-----+
# | movie|34387|
# |  film|25417|
# |  like|20361|
# |   one|20025|
# |  even|12978|
# |  good|11263|
# |really|11183|
# |   bad|10101|
# |   see| 9669|
# |   get| 9534|
# |     -| 9019|
# |  much| 8792|
# |  make| 8730|
# |  time| 7596|
# |people| 7594|
# |  made| 7293|
# | />The| 7184|
# | story| 7110|
# | first| 6588|
# | think| 6556|
# +------+-----+
# only showing top 20 rows

# %% [markdown]
# # Modelling
#
# For this exercise we will not be removing stopwords and see if our model is able to identify to most appropriate words without cleaning the data.

# %%
from pyspark.ml.feature import Tokenizer, CountVectorizer,StringIndexer
from pyspark.ml import Pipeline
from pyspark.ml.classification import LogisticRegression

# %% [markdown]
# In the first step we encode the sentimet with a label. This is similar to sklearn's labelencoder.

# %%
si = StringIndexer(inputCol="sentiment",outputCol="label")
df = si.fit(df).transform(df)
df = df.withColumn('label',df['label'].cast('integer'))

# %%
df.show()
# Out:
# +--------------------+---------+-----+
# |              review|sentiment|label|
# +--------------------+---------+-----+
# |One of the other ...| positive|    1|
# |A wonderful littl...| positive|    1|
# |I thought this wa...| positive|    1|
# |Basically there's...| negative|    0|
# |Petter Mattei's "...| positive|    1|
# |Probably my all-t...| positive|    1|
# |I sure would like...| positive|    1|
# |This show was an ...| negative|    0|
# |Encouraged by the...| negative|    0|
# |If you like origi...| positive|    1|
# |Phil the Alien is...| negative|    0|
# |I saw this movie ...| negative|    0|
# |So im not a big f...| negative|    0|
# |The cast played S...| negative|    0|
# |This a fantastic ...| positive|    1|
# |Kind of drawn in ...| negative|    0|
# |Some films just s...| positive|    1|
# |This movie made i...| negative|    0|
# |I remember this f...| positive|    1|
# |An awful film! It...| negative|    0|
# +--------------------+---------+-----+
# only showing top 20 rows

# %% [markdown]
# Split into training and validationd data.

# %%
train_df,val_df = df.randomSplit([0.8,0.2])

# %%
train_df.show()
# Out:
# +--------------------+---------+-----+
# |              review|sentiment|label|
# +--------------------+---------+-----+
# |\b\b\b\bA Turkish...| positive|    1|
# |!!!! MILD SPOILER...| negative|    0|
# |" Now in India's ...| positive|    1|
# |" Så som i himmel...| positive|    1|
# |" While sporadica...| negative|    0|
# |"... the beat is ...| positive|    1|
# |"2001: A Space Od...| positive|    1|
# |"200l: A Space Od...| positive|    1|
# |"8 SIMPLE RULES.....| positive|    1|
# |"9/11," hosted by...| positive|    1|
# |"A Cry in the Dar...| positive|    1|
# |"A Guy Thing" may...| positive|    1|
# |"A Minute to Pray...| positive|    1|
# |"A Slight Case of...| positive|    1|
# |"A Tale of Two Si...| positive|    1|
# |"A Thief in the N...| positive|    1|
# |"A bored televisi...| negative|    0|
# |"A death at a col...| negative|    0|
# |"A total waste of...| negative|    0|
# |"A trio of treasu...| negative|    0|
# +--------------------+---------+-----+
# only showing top 20 rows

# %% [markdown]
# Write the pipeline. First we tokenized then we use a count vectorizer followed by logistic regression.

# %%
tokenizer = Tokenizer(inputCol="review",outputCol="tokens")
cv = CountVectorizer(binary=True,inputCol="tokens",outputCol="features")
lr = LogisticRegression()
pipeline = Pipeline(stages=[tokenizer,cv,lr])

# %%
model = pipeline.fit(train_df)

# %%
pred = model.transform(val_df)

# %%
pred.show()
# Out:
# +--------------------+---------+-----+--------------------+--------------------+--------------------+--------------------+----------+
# |              review|sentiment|label|              tokens|            features|       rawPrediction|         probability|prediction|
# +--------------------+---------+-----+--------------------+--------------------+--------------------+--------------------+----------+
# |!!!! MILD SPOILER...| negative|    0|[!!!!, mild, spoi...|(262144,[0,1,2,3,...|[53.1570142981802...|           [1.0,0.0]|       0.0|
# |!!!! POSSIBLE MIL...| negative|    0|[!!!!, possible, ...|(262144,[0,1,2,3,...|[-9.3802594344848...|[8.43661920924515...|       1.0|
# |"A Gentleman's Ga...| negative|    0|["a, gentleman's,...|(262144,[0,1,2,3,...|[16.6437362268485...|[0.99999994088234...|       0.0|
# |"A Mouse in the H...| positive|    1|["a, mouse, in, t...|(262144,[0,1,2,3,...|[-35.424210695566...|[4.12534970159587...|       1.0|
# |"A lot of the fil...| negative|    0|["a, lot, of, the...|(262144,[0,1,2,3,...|[-25.188183694804...|[1.15056408190273...|       1.0|
# |"A research scien...| negative|    0|["a, research, sc...|(262144,[0,1,2,3,...|[30.1586273845297...|[0.99999999999992...|       0.0|
# |"A young woman un...| negative|    0|["a, young, woman...|(262144,[0,1,2,3,...|[-3.2639528226136...|[0.03682873626919...|       1.0|
# |"Ah Ritchie's mad...| positive|    1|["ah, ritchie's, ...|(262144,[0,1,2,3,...|[-2.3213912712719...|[0.08936677248432...|       1.0|
# |"Ardh Satya" is o...| positive|    1|["ardh, satya", i...|(262144,[0,1,3,4,...|[-46.120521561684...|[9.33494972366334...|       1.0|
# |"Birth of the Bea...| positive|    1|["birth, of, the,...|(262144,[0,1,2,3,...|[-15.590809405720...|[1.69432778610965...|       1.0|
# |"Boogie Nights" i...| positive|    1|["boogie, nights"...|(262144,[0,1,5,6,...|[-24.345280086513...|[2.67287837922796...|       1.0|
# |"Buffalo Bill, He...| positive|    1|["buffalo, bill,,...|(262144,[0,1,2,3,...|[16.2063870063120...|[0.99999990845059...|       0.0|
# |"Children of wax"...| positive|    1|["children, of, w...|(262144,[0,1,2,3,...|[-43.506456683159...|[1.27463528119844...|       1.0|
# |"Christmas in Con...| positive|    1|["christmas, in, ...|(262144,[0,1,2,3,...|[-27.808377710292...|[8.37481090232782...|       1.0|
# |"Cinema is dead, ...| positive|    1|["cinema, is, dea...|(262144,[0,1,2,3,...|[-15.536781620268...|[1.78838656285992...|       1.0|
# |"Crossfire" is a ...| positive|    1|["crossfire", is,...|(262144,[0,1,2,3,...|[-53.744247307854...|[4.56215419884694...|       1.0|
# |"Crossfire" is os...| positive|    1|["crossfire", is,...|(262144,[0,1,2,3,...|[-49.043546266697...|[5.01947717147434...|       1.0|
# |"Curse of Monkey ...| positive|    1|["curse, of, monk...|(262144,[0,1,2,3,...|[-35.875050750177...|[2.62823032040369...|       1.0|
# |"Death Wish 3" is...| negative|    0|["death, wish, 3"...|(262144,[0,1,2,3,...|[17.4163363146527...|[0.99999997269883...|       0.0|
# |"Die Sieger" was ...| negative|    0|["die, sieger", w...|(262144,[0,1,2,3,...|[-10.532610897407...|[2.66522348922179...|       1.0|
# +--------------------+---------+-----+--------------------+--------------------+--------------------+--------------------+----------+
# only showing top 20 rows

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator
evaluator = BinaryClassificationEvaluator()
evaluator.evaluate(pred) # gives area under roc by default
# Out:
# 0.9256584970353555

# %%
# Accuracy
acc = pred.filter(pred.prediction.cast('integer')==pred.label).count()/val_df.count()
print(acc)
# can you find out precision and recall? (hint filter the denonminator before counting)
# Out:
# 0.851822346146186

# %%
from pyspark.ml.feature import NGram, VectorAssembler

# %% [markdown]
# For ngrams we need to build each ngram separately and then concatenate the features using the vector assembler.

# %%
def build_ngrams(n=1):
    tokenizer = [Tokenizer(inputCol="review",outputCol="tokens")]
    ngrams = [
              NGram(n=i,inputCol="tokens",outputCol=f"{i}_grams")
              for i in range(1,n+1)
    ]
    
    cv = [
          CountVectorizer(vocabSize=2**14,inputCol=f"{i}_grams",outputCol=f"features_{i}")
          for i in range(1,n+1)
    ]

    assembler =  [
        VectorAssembler(
            inputCols=[f"features_{i}" for i in range(1, n + 1)],
            outputCol="features"
        )
    ]
    lr = [LogisticRegression()]

    return Pipeline(stages=tokenizer+ngrams+cv+assembler+lr)

# %%
pipeline = build_ngrams(2)

# %%
model = pipeline.fit(train_df)

# %%
pred = model.transform(val_df)

# %%
evaluator.evaluate(pred)
# Out:
# 0.9424111201549831

# %%
acc = pred.filter(pred.prediction.cast('integer')==pred.label).count()/val_df.count()
print(acc)
# Out:
# 0.8752240589524

# %%
pred.show()
# Out:
# +--------------------+---------+-----+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------+
# |              review|sentiment|label|              tokens|             1_grams|             2_grams|          features_1|          features_2|            features|       rawPrediction|         probability|prediction|
# +--------------------+---------+-----+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------+
# |!!!! MILD SPOILER...| negative|    0|[!!!!, mild, spoi...|[!!!!, mild, spoi...|[!!!! mild, mild ...|(16384,[0,1,2,3,4...|(16384,[0,1,9,10,...|(32768,[0,1,2,3,4...|[120.446376819478...|           [1.0,0.0]|       0.0|
# |!!!! POSSIBLE MIL...| negative|    0|[!!!!, possible, ...|[!!!!, possible, ...|[!!!! possible, p...|(16384,[0,1,2,3,4...|(16384,[2,7,8,9,1...|(32768,[0,1,2,3,4...|[-9.2582439175055...|[9.53134870258401...|       1.0|
# |"A Gentleman's Ga...| negative|    0|["a, gentleman's,...|["a, gentleman's,...|["a gentleman's, ...|(16384,[0,1,2,3,4...|(16384,[0,1,4,5,6...|(32768,[0,1,2,3,4...|[55.0469847159341...|           [1.0,0.0]|       0.0|
# |"A Mouse in the H...| positive|    1|["a, mouse, in, t...|["a, mouse, in, t...|["a mouse, mouse ...|(16384,[0,1,2,3,4...|(16384,[1,2,6,8,1...|(32768,[0,1,2,3,4...|[-66.783235317742...|[9.91766461869720...|       1.0|
# |"A lot of the fil...| negative|    0|["a, lot, of, the...|["a, lot, of, the...|["a lot, lot of, ...|(16384,[0,1,2,3,4...|(16384,[0,1,2,3,4...|(32768,[0,1,2,3,4...|[135.112708883937...|           [1.0,0.0]|       0.0|
# |"A research scien...| negative|    0|["a, research, sc...|["a, research, sc...|["a research, res...|(16384,[0,1,2,3,4...|(16384,[0,2,3,4,8...|(32768,[0,1,2,3,4...|[29.2082622956385...|[0.99999999999979...|       0.0|
# |"A young woman un...| negative|    0|["a, young, woman...|["a, young, woman...|["a young, young ...|(16384,[0,1,2,3,4...|(16384,[0,4,6,7,9...|(32768,[0,1,2,3,4...|[24.4023137238897...|[0.99999999997475...|       0.0|
# |"Ah Ritchie's mad...| positive|    1|["ah, ritchie's, ...|["ah, ritchie's, ...|["ah ritchie's, r...|(16384,[0,1,2,3,4...|(16384,[3,4,26,72...|(32768,[0,1,2,3,4...|[-8.9103300243062...|[1.34969058448414...|       1.0|
# |"Ardh Satya" is o...| positive|    1|["ardh, satya", i...|["ardh, satya", i...|["ardh satya", sa...|(16384,[0,1,3,4,5...|(16384,[0,1,2,4,6...|(32768,[0,1,3,4,5...|[-132.18877942927...|[3.90069976663410...|       1.0|
# |"Birth of the Bea...| positive|    1|["birth, of, the,...|["birth, of, the,...|["birth of, of th...|(16384,[0,1,2,3,4...|(16384,[0,1,3,7,1...|(32768,[0,1,2,3,4...|[-63.341523401635...|[3.09831743797228...|       1.0|
# |"Boogie Nights" i...| positive|    1|["boogie, nights"...|["boogie, nights"...|["boogie nights",...|(16384,[0,1,5,6,8...|(16384,[2,5,8,17,...|(32768,[0,1,5,6,8...|[-53.559171217401...|[5.48968575554156...|       1.0|
# |"Buffalo Bill, He...| positive|    1|["buffalo, bill,,...|["buffalo, bill,,...|["buffalo bill,, ...|(16384,[0,1,2,3,4...|(16384,[0,1,3,4,6...|(32768,[0,1,2,3,4...|[92.9308489389378...|           [1.0,0.0]|       0.0|
# |"Children of wax"...| positive|    1|["children, of, w...|["children, of, w...|["children of, of...|(16384,[0,1,2,3,4...|(16384,[0,1,2,3,7...|(32768,[0,1,2,3,4...|[-27.049052874757...|[1.78955724692247...|       1.0|
# |"Christmas in Con...| positive|    1|["christmas, in, ...|["christmas, in, ...|["christmas in, i...|(16384,[0,1,2,3,4...|(16384,[0,1,2,3,6...|(32768,[0,1,2,3,4...|[-55.013090556776...|[1.28268004616201...|       1.0|
# |"Cinema is dead, ...| positive|    1|["cinema, is, dea...|["cinema, is, dea...|["cinema is, is d...|(16384,[0,1,2,3,4...|(16384,[0,1,2,4,7...|(32768,[0,1,2,3,4...|[-26.743756222545...|[2.42847841213105...|       1.0|
# |"Crossfire" is a ...| positive|    1|["crossfire", is,...|["crossfire", is,...|["crossfire" is, ...|(16384,[0,1,2,3,4...|(16384,[0,1,2,7,9...|(32768,[0,1,2,3,4...|[-116.08274236125...|[3.85394531772009...|       1.0|
# |"Crossfire" is os...| positive|    1|["crossfire", is,...|["crossfire", is,...|["crossfire" is, ...|(16384,[0,1,2,3,4...|(16384,[0,1,2,3,5...|(32768,[0,1,2,3,4...|[-129.13129744802...|[8.29831807444521...|       1.0|
# |"Curse of Monkey ...| positive|    1|["curse, of, monk...|["curse, of, monk...|["curse of, of mo...|(16384,[0,1,2,3,4...|(16384,[0,2,3,4,6...|(32768,[0,1,2,3,4...|[-55.100369073634...|[1.17547598386849...|       1.0|
# |"Death Wish 3" is...| negative|    0|["death, wish, 3"...|["death, wish, 3"...|["death wish, wis...|(16384,[0,1,2,3,4...|(16384,[6,10,12,1...|(32768,[0,1,2,3,4...|[32.3712374788685...|[0.99999999999999...|       0.0|
# |"Die Sieger" was ...| negative|    0|["die, sieger", w...|["die, sieger", w...|["die sieger", si...|(16384,[0,1,2,3,4...|(16384,[0,6,7,8,1...|(32768,[0,1,2,3,4...|[22.8481174111267...|[0.99999999988054...|       0.0|
# +--------------------+---------+-----+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------+
# only showing top 20 rows
